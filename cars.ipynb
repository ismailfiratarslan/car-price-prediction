# %% [markdown]
# https://nbviewer.org/github/Tanu-N-Prabhu/Python/blob/master/Exploratory_data_Analysis.ipynb?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDS0105ENSkillsNetwork20083975-2022-01-01

# %% [markdown]
# # 1. Importing the required libraries for EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns                      
import matplotlib.pyplot as plt  


from sklearn.model_selection import train_test_split # splitting train and test part
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler # for normalization 
from sklearn.impute import SimpleImputer # for missing data
from sklearn.preprocessing import LabelEncoder # for categorical datas
from sklearn.preprocessing import OneHotEncoder # vectoral representation for categorical datas
import missingno as msno # plot for null values
import statsmodels.api as sm
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score,roc_curve, precision_score, recall_score, f1_score, auc
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from yellowbrick.classifier import ConfusionMatrix
from pandas_profiling import ProfileReport
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import GridSearchCV


# Modules for Prediction
from sklearn.linear_model import LogisticRegression, LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # 2. Loading the data into the data frame.

# %%
df = pd.read_csv("cars-last.csv")
df.head()
# Out:
#     İlan No      İlan Tarihi    Marka     Seri            Model   Yıl  \
# 0  20862633  27 Ağustos 2022     Fiat     Egea  1.4 Fire Street  2021
# 1  20862380  27 Ağustos 2022  Renault     Clio    1.0 TCe Touch  2021
# 2  20862220  27 Ağustos 2022  Renault  Fluence     1.5 dCi Icon  2015
# 3  20861832  27 Ağustos 2022    Skoda   SuperB   1.6 TDI Active  2017
# 4  20861631  27 Ağustos 2022    Honda   Accord    2.0 Executive  2011
#
#     Kilometre     Vites Tipi Yakıt Tipi    Kasa Tipi Motor Hacmi Motor Gücü  \
# 0   27.000 km            Düz     Benzin  Hatchback/5     1368 cc      95 hp
# 1   21.000 km       Otomatik     Benzin  Hatchback/5      999 cc     100 hp
# 2  121.000 km  Yarı Otomatik      Dizel        Sedan     1461 cc     110 hp
# 3  154.000 km  Yarı Otomatik      Dizel  Hatchback/5     1598 cc     120 hp
# 4  132.500 km       Otomatik     Benzin        Sedan     1998 cc     156 hp
#
#          Çekiş Ort. Yakıt Tüketimi Yakıt Deposu    Boya-değişen  \
# 0  Önden Çekiş              6,6 lt        50 lt  Tamamı orjinal
# 1  Önden Çekiş                5 lt        42 lt   Belirtilmemiş
# 2  Önden Çekiş              4,4 lt        60 lt  Tamamı orjinal
# 3  Önden Çekiş              4,1 lt        66 lt  Tamamı orjinal
# 4  Önden Çekiş              7,3 lt        65 lt        4 boyalı
#
#          Takasa Uygun      Kimden      TL
# 0        Takasa Uygun   Galeriden  362000
# 1        Takasa Uygun   Galeriden  489500
# 2        Takasa Uygun   Galeriden  422000
# 3  Takasa Uygun Değil  Sahibinden  650000
# 4  Takasa Uygun Değil  Sahibinden  445000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2002 entries, 0 to 2001
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   İlan No              2002 non-null   int64
#  1   İlan Tarihi          2002 non-null   object
#  2   Marka                2002 non-null   object
#  3   Seri                 2002 non-null   object
#  4   Model                2002 non-null   object
#  5   Yıl                  2002 non-null   int64
#  6   Kilometre            2002 non-null   object
#  7   Vites Tipi           2002 non-null   object
#  8   Yakıt Tipi           2002 non-null   object
#  9   Kasa Tipi            2002 non-null   object
#  10  Motor Hacmi          2002 non-null   object
#  11  Motor Gücü           2002 non-null   object
#  12  Çekiş                2002 non-null   object
#  13  Ort. Yakıt Tüketimi  2002 non-null   object
#  14  Yakıt Deposu         2002 non-null   object
#  15  Boya-değişen         2002 non-null   object
#  16  Takasa Uygun         2002 non-null   object
#  17  Kimden               2002 non-null   object
#  18  TL                   2002 non-null   int64
# dtypes: int64(3), object(16)
# memory usage: 297.3+ KB

# %%
df.describe().T
# Out:
#           count          mean            std        min          25%  \
# İlan No  2002.0  2.069110e+07  552009.890824  7309093.0  20810311.25
# Yıl      2002.0  2.012344e+03       6.589012     1974.0      2010.00
# TL       2002.0  4.560559e+05  736589.222395    39000.0    234600.00
#
#                 50%          75%         max
# İlan No  20836959.5  20849568.75  20862917.0
# Yıl          2014.0      2017.00      2022.0
# TL         338000.0    485000.00  21950000.0

# %%
df.describe(exclude=["float", "int"]).T
# Out:
#                     count unique                 top  freq
# İlan Tarihi          2002      6     23 Ağustos 2022   401
# Marka                2002     37             Renault   370
# Seri                 2002    182                Clio   123
# Model                2002    814       1.5 dCi Touch    54
# Kilometre            2002    796          130.000 km    21
# Vites Tipi           2002      5                 Düz  1041
# Yakıt Tipi           2002      6               Dizel  1083
# Kasa Tipi            2002     10               Sedan  1059
# Motor Hacmi          2002    121             1598 cc   366
# Motor Gücü           2002    124               90 hp   243
# Çekiş                2002      5         Önden Çekiş  1798
# Ort. Yakıt Tüketimi  2002     75              4,2 lt   121
# Yakıt Deposu         2002     48               45 lt   396
# Boya-değişen         2002     68       Belirtilmemiş   717
# Takasa Uygun         2002      4  Takasa Uygun Değil  1356
# Kimden               2002      4          Sahibinden  1396

# %% [markdown]
# # 3. Checking the types of data

# %%
df.dtypes
# Out:
# İlan No                 int64
# İlan Tarihi            object
# Marka                  object
# Seri                   object
# Model                  object
# Yıl                     int64
# Kilometre              object
# Vites Tipi             object
# Yakıt Tipi             object
# Kasa Tipi              object
# Motor Hacmi            object
# Motor Gücü             object
# Çekiş                  object
# Ort. Yakıt Tüketimi    object
# Yakıt Deposu           object
# Boya-değişen           object
# Takasa Uygun           object
# Kimden                 object
# TL                      int64
# dtype: object

# %%
# df["TL"] = df["TL"].apply(lambda x: x.replace(".", ""))
# df["TL"] = df["TL"].apply(lambda x: x.replace(",", ""))

# df["TL"] = df["TL"].apply(pd.to_numeric, errors="coerce")
# print(df["TL"])

# %%
df["Kilometre"] = df["Kilometre"].apply(lambda x: x.replace(".", ""))
df["Kilometre"] = df["Kilometre"].apply(lambda x: x.strip("km"))
df["Kilometre"] = df["Kilometre"].astype(int)

# %%
df = df[df["Motor Hacmi"].isin(["Sedan"]) == False]
df["Motor Hacmi"] = df["Motor Hacmi"].apply(lambda x: x.strip("cc"))
df["Motor Hacmi"] = df["Motor Hacmi"].astype(int)

# %%
df["Ort. Yakıt Tüketimi"] = df["Ort. Yakıt Tüketimi"].apply(lambda x: x.replace(",", "."))
df["Ort. Yakıt Tüketimi"] = df["Ort. Yakıt Tüketimi"].apply(lambda x: x.strip("lt"))
df["Ort. Yakıt Tüketimi"] = df["Ort. Yakıt Tüketimi"].astype(float)

# %%
df["Yakıt Deposu"] = df["Yakıt Deposu"].apply(lambda x: x.replace(",", "."))
df["Yakıt Deposu"] = df["Yakıt Deposu"].apply(lambda x: x.strip("lt"))
df["Yakıt Deposu"] = df["Yakıt Deposu"].astype(float)

# %%
df = df[~df['Motor Gücü'].str.contains("-")]
df = df[~df['Motor Gücü'].str.contains("ve")]
df["Motor Gücü"] = df["Motor Gücü"].apply(lambda x: x.strip("hp"))
df["Motor Gücü"] = df["Motor Gücü"].astype(int)

# %% [markdown]
# # 4. Dropping irrelevant columns

# %%
df = df.drop(["İlan No", "İlan Tarihi"], axis=1)

# %%
df.head()
# Out:
#      Marka     Seri            Model   Yıl  Kilometre     Vites Tipi  \
# 0     Fiat     Egea  1.4 Fire Street  2021      27000            Düz
# 1  Renault     Clio    1.0 TCe Touch  2021      21000       Otomatik
# 2  Renault  Fluence     1.5 dCi Icon  2015     121000  Yarı Otomatik
# 3    Skoda   SuperB   1.6 TDI Active  2017     154000  Yarı Otomatik
# 4    Honda   Accord    2.0 Executive  2011     132500       Otomatik
#
#   Yakıt Tipi    Kasa Tipi  Motor Hacmi  Motor Gücü        Çekiş  \
# 0     Benzin  Hatchback/5         1368          95  Önden Çekiş
# 1     Benzin  Hatchback/5          999         100  Önden Çekiş
# 2      Dizel        Sedan         1461         110  Önden Çekiş
# 3      Dizel  Hatchback/5         1598         120  Önden Çekiş
# 4     Benzin        Sedan         1998         156  Önden Çekiş
#
#    Ort. Yakıt Tüketimi  Yakıt Deposu    Boya-değişen        Takasa Uygun  \
# 0                  6.6          50.0  Tamamı orjinal        Takasa Uygun
# 1                  5.0          42.0   Belirtilmemiş        Takasa Uygun
# 2                  4.4          60.0  Tamamı orjinal        Takasa Uygun
# 3                  4.1          66.0  Tamamı orjinal  Takasa Uygun Değil
# 4                  7.3          65.0        4 boyalı  Takasa Uygun Değil
#
#        Kimden      TL
# 0   Galeriden  362000
# 1   Galeriden  489500
# 2   Galeriden  422000
# 3  Sahibinden  650000
# 4  Sahibinden  445000

# %% [markdown]
# # 6. Dropping the duplicate rows

# %%
df.shape
# Out:
# (1995, 17)

# %%
duplicate_rows_df = df[df.duplicated()]
print("Number of duplicate:", duplicate_rows_df.shape)
# Out:
# Number of duplicate: (1, 17)

# %%
df = df.drop_duplicates()

# %% [markdown]
# # 7. Dropping the missing or null values.

# %%
df.isnull().sum()
# Out:
# Marka                  0
# Seri                   0
# Model                  0
# Yıl                    0
# Kilometre              0
# Vites Tipi             0
# Yakıt Tipi             0
# Kasa Tipi              0
# Motor Hacmi            0
# Motor Gücü             0
# Çekiş                  0
# Ort. Yakıt Tüketimi    0
# Yakıt Deposu           0
# Boya-değişen           0
# Takasa Uygun           0
# Kimden                 0
# TL                     0
# dtype: int64

# %%
df = df.dropna()

# %%
df.count()
# Out:
# Marka                  1994
# Seri                   1994
# Model                  1994
# Yıl                    1994
# Kilometre              1994
# Vites Tipi             1994
# Yakıt Tipi             1994
# Kasa Tipi              1994
# Motor Hacmi            1994
# Motor Gücü             1994
# Çekiş                  1994
# Ort. Yakıt Tüketimi    1994
# Yakıt Deposu           1994
# Boya-değişen           1994
# Takasa Uygun           1994
# Kimden                 1994
# TL                     1994
# dtype: int64

# %% [markdown]
# # 8. Detecting Outliers

# %%
# sns.boxplot(x = "TL", data = df)
# %matplotlib inline
sns.boxplot(x=df['TL'])
# Out:
# <AxesSubplot:xlabel='TL'>

# %%
sns.boxplot(x = df["Motor Hacmi"])
# Out:
# <AxesSubplot:xlabel='Motor Hacmi'>

# %%
sns.boxplot(x = df["Kilometre"])
# Out:
# <AxesSubplot:xlabel='Kilometre'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Yıl                         7.00
# Kilometre              113992.75
# Motor Hacmi               230.00
# Motor Gücü                 31.00
# Ort. Yakıt Tüketimi         1.90
# Yakıt Deposu               11.00
# TL                     250075.00
# dtype: float64

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# (1584, 17)

# %%
df.head()
# Out:
#      Marka     Seri             Model   Yıl  Kilometre     Vites Tipi  \
# 0     Fiat     Egea   1.4 Fire Street  2021      27000            Düz
# 2  Renault  Fluence      1.5 dCi Icon  2015     121000  Yarı Otomatik
# 3    Skoda   SuperB    1.6 TDI Active  2017     154000  Yarı Otomatik
# 6     Ford    Focus  1.5 TDCi Trend X  2017     144500  Yarı Otomatik
# 8    Skoda  Octavia   1.6 TDI Optimal  2018     120000  Yarı Otomatik
#
#   Yakıt Tipi      Kasa Tipi  Motor Hacmi  Motor Gücü        Çekiş  \
# 0     Benzin    Hatchback/5         1368          95  Önden Çekiş
# 2      Dizel          Sedan         1461         110  Önden Çekiş
# 3      Dizel    Hatchback/5         1598         120  Önden Çekiş
# 6      Dizel  Station wagon         1499         120  Önden Çekiş
# 8      Dizel    Hatchback/5         1598         115  Önden Çekiş
#
#    Ort. Yakıt Tüketimi  Yakıt Deposu    Boya-değişen        Takasa Uygun  \
# 0                  6.6          50.0  Tamamı orjinal        Takasa Uygun
# 2                  4.4          60.0  Tamamı orjinal        Takasa Uygun
# 3                  4.1          66.0  Tamamı orjinal  Takasa Uygun Değil
# 6                  4.2          53.0   Belirtilmemiş  Takasa Uygun Değil
# 8                  3.9          50.0   Belirtilmemiş        Takasa Uygun
#
#        Kimden      TL
# 0   Galeriden  362000
# 2   Galeriden  422000
# 3  Sahibinden  650000
# 6   Galeriden  470000
# 8   Galeriden  539000

# %% [markdown]
# # 9. Plot different features against one another (scatter), against frequency (histogram)

# %% [markdown]
# ### Histogram
# Histogram, bir aralıktaki değişkenlerin ortaya çıkma sıklığını ifade eder

# %%
df["Marka"].value_counts().nlargest(40).plot(kind = "bar", figsize=(10,5))
plt.title("Araba Markalarının Dağılımı")
plt.xlabel("Araba Markası")
plt.ylabel("Araba Sayısı")
# Out:
# Text(0, 0.5, 'Araba Sayısı')

# %% [markdown]
# ### Heat Maps

# %%
correlation = df.corr()
sns.heatmap(correlation, cmap="BrBG", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Scatterplot
# İki değişken arasındaki korelasyonu bulmak için genellikle dağılım grafiklerini kullanırız.

# %%
fig, axis = plt.subplots(figsize=(10, 5))
axis.scatter(x = df["Motor Hacmi"], y = df["TL"])
axis.set_xlabel("Motor Hacmi")
axis.set_ylabel("Araba Fiyatı")
# Out:
# Text(0, 0.5, 'Araba Fiyatı')

# %% [markdown]
# # Label Encoding

# %%
le = LabelEncoder()

df["Marka"] = le.fit_transform(df["Marka"])
dict_Marka = dict(zip(le.classes_, le.transform(le.classes_)))

df["Seri"] = le.fit_transform(df["Seri"])
dict_Seri = dict(zip(le.classes_, le.transform(le.classes_)))

df["Model"] = le.fit_transform(df["Model"])
dict_Model = dict(zip(le.classes_, le.transform(le.classes_)))

df["Vites Tipi"] = le.fit_transform(df["Vites Tipi"])
dict_VitesTipi = dict(zip(le.classes_, le.transform(le.classes_)))

df["Yakıt Tipi"] = le.fit_transform(df["Yakıt Tipi"])
dict_YakıtTipi = dict(zip(le.classes_, le.transform(le.classes_)))

df["Kasa Tipi"] = le.fit_transform(df["Kasa Tipi"])
dict_KasaTipi = dict(zip(le.classes_, le.transform(le.classes_)))

# df["Motor Gücü"] = le.fit_transform(df["Motor Gücü"])
# dict_MotorGücü	 = dict(zip(le.classes_, le.transform(le.classes_)))

df["Çekiş"] = le.fit_transform(df["Çekiş"])
dict_Cekiş = dict(zip(le.classes_, le.transform(le.classes_)))

df["Boya-değişen"] = le.fit_transform(df["Boya-değişen"])
dict_BoyaDegisen = dict(zip(le.classes_, le.transform(le.classes_)))

df["Takasa Uygun"] = le.fit_transform(df["Takasa Uygun"])
dict_TakasaUygun = dict(zip(le.classes_, le.transform(le.classes_)))

df["Kimden"] = le.fit_transform(df["Kimden"])
dict_Kimden= dict(zip(le.classes_, le.transform(le.classes_)))

# %%
print("Markalar\n", dict_Marka)
print("Serileri\n", dict_Seri)
print("Modelleri\n", dict_Model)
print("Vites Tipleri\n", dict_VitesTipi)
print("Yakıt Tipleri\n", dict_YakıtTipi)
print("Kasa Tipleri\n", dict_KasaTipi)
# print("Motor Güçleri\n", dict_MotorGücü)
print("Boya Değişme Durumu\n", dict_BoyaDegisen)
print("Takasa Uygunluk\n", dict_TakasaUygun)
print("Kimden Olduğu\n", dict_Kimden)
# Out:
# Markalar
#  {'Alfa Romeo': 0, 'Audi': 1, 'BMW': 2, 'Chevrolet': 3, 'Citroen': 4, 'Dacia': 5, 'Fiat': 6, 'Ford': 7, 'Geely': 8, 'Honda': 9, 'Hyundai': 10, 'Kia': 11, 'Lada': 12, 'Lancia': 13, 'MINI': 14, 'Mercedes - Benz': 15, 'Mitsubishi': 16, 'Nissan': 17, 'Opel': 18, 'Peugeot': 19, 'Renault': 20, 'Saab': 21, 'Seat': 22, 'Skoda': 23, 'Smart': 24, 'Suzuki': 25, 'Tofaş': 26, 'Toyota': 27, 'Volkswagen': 28, 'Volvo': 29}
# Serileri
#  {'1 Serisi': 0, '106': 1, '156': 2, '206': 3, '207': 4, '208': 5, '3 Serisi': 6, '301': 7, '306': 8, '307': 9, '308': 10, '407': 11, '500 Ailesi': 12, '508': 13, '9-3': 14, 'A': 15, 'A1': 16, 'A3': 17, 'A4': 18, 'Accent': 19, 'Accent Blue': 20, 'Accent Era': 21, 'Albea': 22, 'Almera': 23, 'Altea': 24, 'Alto': 25, 'Astra': 26, 'Auris': 27, 'Avensis': 28, 'Aveo': 29, 'B': 30, 'B-Max': 31, 'Bora': 32, 'Brava': 33, 'Bravo': 34, 'C': 35, 'C-Elysee': 36, 'C-Max': 37, 'C3': 38, 'C4': 39, 'C4 Grand Picasso': 40, 'C4 Picasso': 41, 'C5': 42, 'CLA': 43, 'Ceed': 44, 'Cerato': 45, 'City': 46, 'Civic': 47, 'Clio': 48, 'Cooper': 49, 'Corolla': 50, 'Corsa': 51, 'Cruze': 52, 'Delta': 53, 'Doğan': 54, 'Egea': 55, 'Elantra': 56, 'Emgrand': 57, 'FC': 58, 'Fabia': 59, 'Felicia': 60, 'Fiesta': 61, 'Fluence': 62, 'Focus': 63, 'ForFour': 64, 'Getz': 65, 'Giulietta': 66, 'Golf': 67, 'Grand Scenic': 68, 'Ibiza': 69, 'Insignia': 70, 'Jazz': 71, 'Jetta': 72, 'Kalos': 73, 'Lacetti': 74, 'Laguna': 75, 'Leon': 76, 'Linea': 77, 'Lodgy': 78, 'Logan': 79, 'Matrix': 80, 'Megane': 81, 'Meriva': 82, 'Micra': 83, 'Modus': 84, 'Mondeo': 85, 'New Beetle': 86, 'Note': 87, 'Octavia': 88, 'Palio': 89, 'Panda': 90, 'Passat': 91, 'Passat Variant': 92, 'Picanto': 93, 'Polo': 94, 'Primera': 95, 'Punto': 96, 'RCZ': 97, 'Rapid': 98, 'Rio': 99, 'S60': 100, 'SX4': 101, 'Sandero': 102, 'Saxo': 103, 'Scala': 104, 'Scenic': 105, 'Scirocco': 106, 'Solenza': 107, 'Space Star': 108, 'Stilo': 109, 'SuperB': 110, 'Swift': 111, 'Symbol': 112, 'Talisman': 113, 'Toledo': 114, 'Twingo': 115, 'V40': 116, 'VW CC': 117, 'Vectra': 118, 'Vega': 119, 'Venga': 120, 'Xsara': 121, 'Yaris': 122, 'i10': 123, 'i20': 124, 'i20 Active': 125, 'i20 Troy': 126, 'i30': 127}
# Modelleri
#  {'1.1 EX': 0, '1.1 GLX': 1, '1.1 Hiper': 2, '1.1 Team': 3, '1.2 Active': 4, '1.2 Alize': 5, '1.2 Ambiance': 6, '1.2 Ambiente': 7, '1.2 Authentique': 8, '1.2 Authentique Edition': 9, '1.2 CVT': 10, '1.2 Classic': 11, '1.2 D-CVVT Elite': 12, '1.2 D-CVVT Jump': 13, '1.2 D-CVVT Sense': 14, '1.2 Dynamic': 15, '1.2 EL': 16, '1.2 Edition': 17, '1.2 Elegance': 18, '1.2 Enjoy': 19, '1.2 Essentia': 20, '1.2 Essential': 21, '1.2 Fire Urban': 22, '1.2 GLX': 23, '1.2 Joy': 24, '1.2 LS': 25, '1.2 MPI Elite Blue': 26, '1.2 MPI Jump': 27, '1.2 MPI Style': 28, '1.2 MPI Team': 29, '1.2 Match': 30, '1.2 Mood': 31, '1.2 Passion': 32, '1.2 Punch': 33, '1.2 PureTech Active': 34, '1.2 PureTech Allure': 35, '1.2 PureTech Feel': 36, '1.2 PureTech Feel Bold': 37, '1.2 PureTech GT': 38, '1.2 PureTech Live': 39, '1.2 PureTech SX Edition': 40, '1.2 PureTech Shine':
C': 138, '1.4 DOHC HY KLM': 139, '1.4 Design': 140, '1.4 Desire': 141, '1.4 ES': 142, '1.4 ES Elite': 143, '1.4 EX Trend': 144, '1.4 Elite': 145, '1.4 Enjoy': 146, '1.4 Essentia': 147, '1.4 Expression': 148, '1.4 Fire Active': 149, '1.4 Fire Dynamic': 150, '1.4 Fire Easy': 151, '1.4 Fire Easy Plus': 152, '1.4 Fire Lounge': 153, '1.4 Fire Mirror': 154, '1.4 Fire Pop': 155, '1.4 Fire Street': 156, '1.4 Fire Urban': 157, '1.4 Fire Urban Plus': 158, '1.4 Fun': 159, '1.4 GL': 160, '1.4 HDi': 161, '1.4 HDi Active': 162, '1.4 HDi Attraction': 163, '1.4 HDi Collection': 164, '1.4 HDi Comfort': 165, '1.4 HDi Fever': 166, '1.4 HDi Profil': 167, '1.4 HDi SX': 168, '1.4 HDi Sportium': 169, '1.4 HDi Sporty': 170, '1.4 HDi Trendy': 171, '1.4 HDi X-Design': 172, '1.4 HDi X-line': 173, '1.4 Hybrid': 174, '1.4 LT': 175, '1.4 Linea Terra': 176, '1.4 MPI El ...
# Vites Tipleri
#  {'Düz': 0, 'Otomatik': 1, 'Yarı Otomatik': 2}
# Yakıt Tipleri
#  {'Benzin': 0, 'Dizel': 1, 'Hibrit': 2, 'LPG & Benzin': 3}
# Kasa Tipleri
#  {'-': 0, 'Coupe': 1, 'Hatchback/3': 2, 'Hatchback/5': 3, 'MPV': 4, 'Sedan': 5, 'Station wagon': 6}
# Boya Değişme Durumu
#  {'1 boyalı': 0, '1 değişen': 1, '1 değişen, 1 boyalı': 2, '1 değişen, 10 boyalı': 3, '1 değişen, 11 boyalı': 4, '1 değişen, 12 boyalı': 5, '1 değişen, 2 boyalı': 6, '1 değişen, 3 boyalı': 7, '1 değişen, 4 boyalı': 8, '1 değişen, 5 boyalı': 9, '1 değişen, 6 boyalı': 10, '1 değişen, 7 boyalı': 11, '1 değişen, 8 boyalı': 12, '1 değişen, 9 boyalı': 13, '10 boyalı': 14, '11 boyalı': 15, '12 boyalı': 16, '2 boyalı': 17, '2 değişen': 18, '2 değişen, 1 boyalı': 19, '2 değişen, 10 boyalı': 20, '2 değişen, 11 boyalı': 21, '2 değişen, 2 boyalı': 22, '2 değişen, 3 boyalı': 23, '2 değişen, 4 boyalı': 24, '2 değişen, 5 boyalı': 25, '2 değişen, 6 boyalı': 26, '2 değişen, 7 boyalı': 27, '2 değişen, 8 boyalı': 28, '2 değişen, 9 boyalı': 29, '3 boyalı': 30, '3 değişen': 31, '3 değişen, 1 boyalı': 32, '3 değişen, 10 boyalı': 33, '3 değişen, 2 boyalı': 34, '3 değişen, 3 boyalı': 35, '3 değişen, 4 boyalı': 36, '3 değişen, 5 boyalı': 37, '3 değişen, 6 boyalı': 38, '3 değişen, 7 boyalı': 39, '3 değişen, 8 boyalı': 40, '3 değişen, 9 boyalı': 41, '4 boyalı': 42, '4 değişen': 43, '4 değişen, 2 boyalı': 44, '4 değişen, 3 boyalı': 45, '4 değişen, 5 boyalı': 46, '4 değişen, 6 boyalı': 47, '4 değişen, 7 boyalı': 48, '4 değişen, 8 boyalı': 49, '4 değişen, 9 boyalı': 50, '5 boyalı': 51, '5 değişen': 52, '5 değişen, 6 boyalı': 53, '5 değişen, 8 boyalı': 54, '6 boyalı': 55, '6 değişen, 4 boyalı': 56, '6 değişen, 6 boyalı': 57, '7 boyalı': 58, '8 boyalı': 59, '8 değişen, 2 boyalı': 60, '9 boyalı': 61, '9 değişen, 2 boyalı': 62, 'Belirtilmemiş': 63, 'Tamamı boyalı': 64, 'Tamamı orjinal': 65}
# Takasa Uygunluk
#  {'Takasa Uygun': 0, 'Takasa Uygun Değil': 1}
# Kimden Olduğu
#  {'Galeriden': 0, 'Sahibinden': 1, 'Yetkili Bayiden': 2}

# %% [markdown]
# # Bağımlı Bağımsız Değişkenlerin Ayrılması

# %%
X = df.iloc[:, :-1].values # independent variables
y = df.iloc[:, -1:].values # dependent variables

# %% [markdown]
# # Verilerin Eğitim ve Test için Bölünmesi

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=100)

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (1061, 16)
# X_test shape: (523, 16)
# y_train shape: (1061, 1)
# y_test shape: (523, 1)

# %% [markdown]
# # Model Selection

# %%
models = []
models.append(['Logistic Regression', LogisticRegression()])
models.append(['Linear Regression', LinearRegression()])
models.append(['SVM', SVR()])
models.append(['KNeigbors', KNeighborsRegressor()])
models.append(['DecisionTree', DecisionTreeRegressor()])
models.append(['AdaBoostRegressor', AdaBoostRegressor()])
models.append(['GradientBoostingRegressor', GradientBoostingRegressor()])
models.append(['XGBRegressor', XGBRegressor()])
models.append(['LGBMRegressor', LGBMRegressor()])
models.append(['CatBoostRegressor', CatBoostRegressor()])
models.append(['GaussianNB', GaussianNB()])
models.append(['BernoulliNB', BernoulliNB()])
models.append(['MLPRegressor', MLPRegressor()])
models.append(['RandomForest', RandomForestRegressor()])
models.append(['Ridge', Ridge()])
models.append(['Lasso', Lasso()])

# %%
lst_1 = []
for m in range(len(models)):
    lst_2 = []
    model = models[m][1]
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    MSE = mean_squared_error(y_test, y_pred)
    MAE = mean_absolute_error(y_test, y_pred)
    SCORE = r2_score(y_test, y_pred)
    RMSE = np.sqrt(MSE)
    
    accuracies = cross_val_score(estimator=model, X=X_train, y=y_train, cv=10)

    lst_2.append(models[m][0])
    lst_2.append(MSE)
    lst_2.append(MAE)
    lst_2.append(SCORE)
    lst_2.append(RMSE)
    lst_2.append(accuracies.mean() * 100)
    lst_2.append(accuracies.std() * 100)
    lst_1.append(lst_2)
# Out:
# Learning rate set to 0.041328
# 0:	learn: 150905.7440093	total: 143ms	remaining: 2m 22s
# 1:	learn: 146972.7566118	total: 145ms	remaining: 1m 12s
# 2:	learn: 143236.5459002	total: 146ms	remaining: 48.5s
# 3:	learn: 139690.2972923	total: 148ms	remaining: 36.9s
# 4:	learn: 135974.3092975	total: 150ms	remaining: 29.9s
# 5:	learn: 132542.0074682	total: 152ms	remaining: 25.2s
# 6:	learn: 129149.4238095	total: 155ms	remaining: 22s
# 7:	learn: 125996.7757895	total: 158ms	remaining: 19.5s
# 974:	learn: 16851.3936839	total: 2.33s	remaining: 59.8ms
# 975:	learn: 16845.8778218	total: 2.33s	remaining: 57.4ms
# 976:	learn: 16840.3413090	total: 2.33s	remaining: 55ms
# 977:	learn: 16822.6015818	total: 2.34s	remaining: 52.6ms
# 978:	learn: 16795.6414103	total: 2.34s	remaining: 50.2ms
# 979:	learn: 16790.7527218	total: 2.34s	remaining: 47.8ms
# 980:	learn: 16778.4574260	total: 2.34s	remaining: 45.4ms
# 981:	learn: 16767.0391688	total: 2.34s	remaining: 43ms
# 982:	learn: 16756.7956244	total: 2.35s	remaining: 40.6ms
# 983:	learn: 16747.7986854	total: 2.35s	remaining: 38.2ms
# 984:	learn: 16730.7702585	total: 2.35s	remaining: 35.8ms
# 985:	learn: 16722.1261607	total: 2.35s	remaining: 33.4ms
# 986:	learn: 16710.2319989	total: 2.35s	remaining: 31ms
# 987:	learn: 16698.3188553	total: 2.36s	remaining: 28.6ms
# 988:	learn: 16692.1406849	total: 2.36s	remaining: 26.2ms
# 989:	learn: 16682.3485430	total: 2.36s	remaining: 23.9ms
# 990:	learn: 16675.6148587	total: 2.36s	remaining: 21.5ms
# 991:	learn: 16647.2256063	total: 2.37s	remaining: 19.1ms
# 992:	learn: 16632.0140434	total: 2.37s	remaining: 16.7ms
# 993:	learn: 16617.2135618	total: 2.37s	remaining: 14.3ms
# 994:	learn: 16604.4699341	total: 2.37s	remaining: 11.9ms
# 995:	learn: 16588.1609895	total: 2.38s	remaining: 9.54ms
# 996:	learn: 16564.9565740	total: 2.38s	remaining: 7.16ms
# 997:	learn: 16563.3453345	total: 2.38s	remaining: 4.77ms
# 998:	learn: 16553.8540777	total: 2.38s	remaining: 2.38ms
# 999:	learn: 16537.3978465	total: 2.38s	remaining: 0us

# %%
df_col = pd.DataFrame(lst_1, columns=['Model Name', 'Mean Squared Error', 'Mean Absolute Error', 'R2 Score', 'Root Mean Squared Error',
                      'K-Fold Validation Mean Accuracy', 'Std.Deviation'])

df_col.sort_values(by=["R2 Score", "K-Fold Validation Mean Accuracy"],
                   ascending=False, inplace=True)
df_col
# Out:
#                    Model Name  Mean Squared Error  Mean Absolute Error  \
# 9           CatBoostRegressor        1.874481e+09         31603.479990
# 8               LGBMRegressor        2.069658e+09         32631.968474
# 7                XGBRegressor        2.259453e+09         34879.112646
# 6   GradientBoostingRegressor        2.325888e+09         35640.637227
# 13               RandomForest        2.367672e+09         35377.830631
# 5           AdaBoostRegressor        4.646093e+09         55075.724855
# 4                DecisionTree        4.892127e+09         50442.235182
# 14                      Ridge        5.133478e+09         53628.369041
# 15                      Lasso        5.153657e+09         53649.610652
# 1           Linear Regression        5.153874e+09         53650.175923
# 10                 GaussianNB        9.129434e+09         67734.390057
# 3                   KNeigbors        1.781472e+10        103775.696750
# 0         Logistic Regression        1.789504e+10         97824.351816
# 2                         SVM        2.628321e+10        123951.282813
# 11                BernoulliNB        3.251954e+10        135537.544933
# 12               MLPRegressor        3.553538e+10        146942.434340
#
#     R2 Score  Root Mean Squared Error  K-Fold Validation Mean Accuracy  \
# 9   0.924503             43295.272353                    -19843.585417
# 8   0.916642             45493.494569                        89.623828
# 7   0.908998             47533.706001                        87.827708
# 6   0.906322             48227.460486                        88.952471
# 13  0.904639             48658.726118                        87.665214
# 5   0.812873             68162.251445                        79.765702
# 4   0.802964             69943.743681                        75.632850
# 14  0.793243             71648.295510                        77.519907
# 15  0.792431             71788.975545                        77.516277
# 1   0.792422             71790.484991                        77.516219
# 10  0.632302             95548.071188                         1.507671
# 3   0.282492            133471.777580                        28.213120
# 0   0.279256            133772.354042                         1.414213
# 2  -0.058587            162120.972749                        -4.565702
# 11 -0.309762            180331.756865                         1.414213
# 12 -0.431229            188508.306770                       -60.342210
#
#     Std.Deviation
# 9      679.836862
# 8        1.886050
# 7        2.293590
# 6        1.855728
# 13       2.167803
# 5        4.278961
# 4        6.204065
# 14       4.018709
# 15       4.013084
# 1        4.013216
# 10       1.532412
# 3        8.249757
# 0        0.761142
# 2        4.259521
# 11       0.967127
# 12      21.579773

# %%
sns.barplot(x = "R2 Score", y= "Model Name", data=df_col)
plt.title("Models Compare")
# Out:
# Text(0.5, 1.0, 'Models Compare')

# %% [markdown]
# # Model Tuning

# %%
# import packages for hyperparameters tuning
# from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %%
# grid_models = [

    # (CatBoostRegressor(), [
    #  {
    #      'depth': [6, 8, 10],
    #      'learning_rate': [0.01, 0.05, 0.1],
    #      'iterations': [30, 50, 100]
    #  }
    #  ]),
# ]

# for model, params in grid_models:
#     grid = GridSearchCV(estimator=model, param_grid=params, scoring="accuracy", cv=10, n_jobs=-1)
#     grid.fit(X_train, y_train)
#     best_accuracy = grid.best_score_
#     best_param = grid.best_params_
#     print(f"{model}\n Best Accuracy: {best_accuracy * 100}")
#     print(f"Best Params: {best_param}")
#     print("*" * 40)

# %%
# classifier = CatBoostRegressor(depth= 6, iterations= 30, learning_rate= 0.01)
# classifier.fit(X_train, y_train)
# y_pred = classifier.predict(X_test)

# %%
# MSE = mean_squared_error(y_test, y_pred)
# MAE = mean_absolute_error(y_test, y_pred)
# SCORE = r2_score(y_test, y_pred)
# RMSE = np.sqrt(MSE)

# accuracies = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10)
# print('Mean Squared Error:\n', MSE)
# print('Mean Absolute Error: ', MAE)
# print('R2 Score: ', SCORE)
# print('Root Mean Squared Error: ', RMSE)
# print('K-Fold Validation Mean Accuracy: {:.2f} %'.format(accuracies.mean() * 100))
# print('Standard Deviation: {:.2f} %'.format(accuracies.std() * 100))
# print('*' * 40)

# %%
# params = {
#     'n_estimators': [100, 500, 900, 1100, 1500],
#     'max_depth': [2, 3, 5, 10, 15],
#     'learning_rate': [0.05, 0.1, 0.15, 0.20],
#     'min_child_weight': [1, 2, 3, 4]
# }

# %%
# model = XGBRegressor()
# grid = GridSearchCV(estimator=model, param_grid=params, scoring="accuracy", cv=10, n_jobs=-1)
# grid.fit(X_train, y_train)
# best_accuracy = grid.best_score_
# best_param = grid.best_params_
# print(f"{model}\n Best Accuracy: {best_accuracy * 100}")
# print(f"Best Params: {best_param}")
# print("*" * 40)

# 8m 16.1s => 4000 paramaters
